# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
start ='2010-01-01'
end= '2022-10-31'

df=data.DataReader('AAPL','yahoo',start,end)
#retreive data from yahoo finance
df.head()
#shows top 10 data
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2009-12-31  7.619643  7.520000  7.611786  7.526071  352410800.0   6.415358
# 2010-01-04  7.660714  7.585000  7.622500  7.643214  493729600.0   6.515211
# 2010-01-05  7.699643  7.616071  7.664286  7.656429  601904800.0   6.526476
# 2010-01-06  7.686786  7.526786  7.656429  7.534643  552160000.0   6.422664
# 2010-01-07  7.571429  7.466071  7.562500  7.520714  477131200.0   6.410790

# %%
df=df.reset_index()
df=df.drop(['Date','Adj Close'],axis=1)
df.head()
# Out:
#        High       Low      Open     Close       Volume
# 0  7.619643  7.520000  7.611786  7.526071  352410800.0
# 1  7.660714  7.585000  7.622500  7.643214  493729600.0
# 2  7.699643  7.616071  7.664286  7.656429  601904800.0
# 3  7.686786  7.526786  7.656429  7.534643  552160000.0
# 4  7.571429  7.466071  7.562500  7.520714  477131200.0

# %%
plt.plot(df.Close)

# %%
'''
creating moving average
for prevoius 100 days mean by creating rolling function
stock specialist use this 100 - 200 days moving average to analyze
'''
ma100=df.Close.rolling(100).mean()
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200=df.Close.rolling(200).mean()
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')

# %%
'''
now we split data to train and test
70:30
'''

data_training=pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing =pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])
print(df.shape)
print(data_training.shape)
print(data_testing.shape)
# Out:
# (3231, 5)
# (2261, 1)
# (970, 1)

# %%
'''
we will scale down data between 0 and 1 using minmax scaler
sklearn provides tool for statistics
'''

from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler(feature_range=(0,1))

data_training_array=scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.01304067],
#        [0.01533047],
#        [0.01558878],
#        ...,
#        [0.63231966],
#        [0.60251035],
#        [0.583452  ]])

# %%
'''
price on a particular day is dependent on previous 100 days value
x-train is first 100 y-train is 101 and this goes on
'''
x_train=[]
y_train=[]

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train,y_train=  np.array(x_train), np.array(y_train)

# %%
#ML MODEL

from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

model =Sequential()
model.add(LSTM(units=50, activation='relu', return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.4))

model.add(LSTM(units=120, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 68/68 [==============================] - 17s 184ms/step - loss: 0.0270
# Epoch 2/50
# 68/68 [==============================] - 12s 183ms/step - loss: 0.0068
# Epoch 3/50
# 68/68 [==============================] - 13s 184ms/step - loss: 0.0052
# Epoch 4/50
# 68/68 [==============================] - 12s 171ms/step - loss: 0.0051
# Epoch 5/50
# 68/68 [==============================] - 13s 188ms/step - loss: 0.0046
# Epoch 6/50
# 68/68 [==============================] - 13s 186ms/step - loss: 0.0047
# Epoch 7/50
# 68/68 [==============================] - 11s 167ms/step - loss: 0.0048
# Epoch 8/50
# 68/68 [==============================] - 11s 166ms/step - loss: 0.0043
# Epoch 9/50
# 68/68 [==============================] - 11s 166ms/step - loss: 0.0039
# Epoch 10/50
# 68/68 [==============================] - 11s 164ms/step - loss: 0.0038
# Epoch 11/50
# 68/68 [==============================] - 12s 174ms/step - loss: 0.0038
# Epoch 12/50
# ...

# %%
model.save('keras_model.h5')

# %%
past_100_days=data_training.tail(100)
final_df =past_100_days.append(data_testing, ignore_index=True)
input_data=scaler.fit_transform(final_df)
input_data.shape
# Out:
# C:\Users\kshub\AppData\Local\Temp\ipykernel_21264\1407295302.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df =past_100_days.append(data_testing, ignore_index=True)
# (1070, 1)

# %%
x_test=[]
y_test=[]

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i, 0])

x_test, y_test =np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (970, 100, 1)
# (970,)

# %%
'''
Making Predictions
'''

y_predicted=model.predict(x_test)
y_predicted.shape
# Out:
# 31/31 [==============================] - 3s 66ms/step
# (970, 1)

# %%
y_test
# Out:
# array([0.02556968, 0.02382861, 0.02396517, 0.02654264, 0.02684987,
#        0.        , 0.010361  , 0.00979771, 0.01461125, 0.01898096,
#        0.01981736, 0.01723989, 0.01333105, 0.01857132, 0.02176325,
#        0.02333362, 0.02497227, 0.0189639 , 0.02002218, 0.01793974,
#        0.02657676, 0.02408467, 0.02131943, 0.03936161, 0.04139285,
#        0.04152941, 0.04960314, 0.05460441, 0.05470684, 0.049074  ,
#        0.04816933, 0.04649653, 0.04898865, 0.04777672, 0.04883503,
#        0.04818639, 0.04905691, 0.05093454, 0.04927882, 0.05253905,
#        0.05468976, 0.05486046, 0.05578219, 0.05284628, 0.05595289,
#        0.05745499, 0.05690876, 0.05518478, 0.05173679, 0.05243663,
#        0.06266108, 0.06609201, 0.06745755, 0.07090551, 0.07498506,
#        0.07822822, 0.0756849 , 0.07846719, 0.09029614, 0.08340019,
#        0.07945721, 0.07612869, 0.07899633, 0.07942306, 0.08152257,
#        0.08372451, 0.08846975, 0.09073996, 0.09132031, 0.09355637,
# ...

# %%
y_predicted
# Out:
# array([[0.0924616 ],
#        [0.09096628],
#        [0.08947776],
#        [0.08800653],
#        [0.08656794],
#        [0.08517909],
#        [0.08384149],
#        [0.08254869],
#        [0.08129518],
#        [0.08007982],
#        [0.07890864],
#        [0.07779154],
#        [0.07673657],
#        [0.07574618],
#        [0.07482247],
#        [0.07397088],
#        [0.07319805],
#        [0.07251039],
#        [0.07190821],
#        [0.07138629],
#        [0.07093643],
#        [0.07055387],
#        [0.07023662],
#        [0.0699791 ],
#        [0.0697872 ],
#        [0.06967892],
#        [0.06967069],
#        [0.06978083],
#        [0.07003126],
#        [0.07043806],
#        [0.07100004],
#        [0.07169907],
#        [0.07250638],
#        [0.07339054],
#        [0.07432088],
#        [0.07526916],
#        [0.07621117],
#        [0.07712737],
#        [0.07800543],
#        [0.07883677],
#        [0.07961833],
#        [0.08035436],
#        [0.08105211],
# ...

# %%
scaler.scale_
# Out:
# array([0.00682769])

# %%
scale_factor=1/0.006827694
y_predicted=y_predicted*scale_factor
y_test=y_test*scale_factor

plt.figure(figsize=(12,6))
plt.plot(y_test, 'b', label='Original Price')
plt.plot(y_predicted, 'r', label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
